# %% [markdown]
# <a href="https://colab.research.google.com/github/Anisha-Tasneem/CSE499/blob/main/CSE499_OurData_withDeliveryCharge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import random

# Function to generate random Bengali names
def generate_bengali_name(gender):
    if gender.lower() == 'female':

        female_names = ['Ayesha', 'Farhana', 'Nusrat', 'Saima', 'Maria', 'Rabeya', 'Tahmina', 'Sharmin', 'Nazia', 'Sabina', 'Alishba', 'Arabi', 'Farinaj', 'Ilma', 'Tashpia', 'Tashfia', 'Abonty','Urmi', 'Anisha' , 'Nafisa','Miniba', 'Raisa', 'Raisa', 'Sujana', 'Irina', 'Labiba', 'Wamia', 'Himeka', 'Lamia', 'Jannatul', 'Tamanna', 'Faiza', 'Sumaiya', 'Fabliha', 'Nowshin', 'Labony', 'Lamisa', 'Mahbuba']
        last_names = ['Akhtar', 'Sultana', 'Ferdous','Ahmed', 'Das', 'Chowdhury', 'Biswas', 'Tasnim', 'Khan', 'Tasneem', 'Sabah', 'Karim', 'Nur', 'Noor', 'Mahi', 'Sobhan', 'Tabassum', 'Fairooz', 'Tahsin', 'Haque', 'Islam', 'Nawar', 'Sabrin', 'Rowshan']
        return random.choice(female_names) + ' ' + random.choice(last_names)
    else:
        male_names = ['Ahmed', 'Ali', 'Rahim', 'Karim', 'Nasir', 'Imran', 'Fahim', 'Jamil', 'Sobhan', 'Shahid', 'Mehedi', 'Mahir','Nafis', 'iqdidar', 'Parthib', 'Samin', 'Nafi', 'Mostafa', 'Mohammad', 'Farib', 'Farid', 'Fayaz', 'Ratul', 'Shafi' , 'Shafin', 'Farhan', 'Mashir', 'Abrar', 'Aminul', 'Abdullah', 'Tanjim', 'Sadman', 'Rohhan', 'Rafid', 'Simanto', 'Rabbi', 'Fazle', 'Salman', 'Rifat']
        last_names = ['Khan', 'Haque', 'Amin', 'Rahman', 'Hasan', 'Barua', 'Uddin', 'Shakil', 'Kabir', 'Shah', 'Murtaza', 'Ibnat', 'Alam', 'Chowdhury', 'Morshed', 'Zaman', 'Islam', 'Yasir', 'Sakib', 'Nain', 'Hassan', 'Hossain', 'Abdullah', 'Amirul', 'Zamil', 'Sadiq' ]
        return random.choice(male_names) + ' ' + random.choice(last_names)

# Function to generate random Bangladeshi addresses
def generate_address(city):
    city_addresses = {
        'Dhaka': [
            'House #7, Road #1, Gulshan 1',
            'Apartment #12, Block #C, Banani',
            'Plot #5, Sector #6, Uttara',
            'Flat #3A, Building #9, Dhanmondi',
            'House #15, Lane #4, Mirpur'
        ],
        'Chittagong': [
            'House #9, Lane #2, Panchlaish',
            'Apartment #5B, Block #D, Nasirabad',
            'Plot #3, GEC Circle, GEC',
            'Flat #8, Building #7, Agrabad',
            'House #21, Road #6, Jamal Khan'
        ],
        'Sylhet': [
            'House #2, Lane #8, Amberkhana',
            'Apartment #15, Block #E, Zindabazar',
            'Plot #10, Shahjalal Uposhohor',
            'Flat #4, Building #11, Lamabazar',
            'House #18, Road #3, Kajalshah'
        ],
        'Khulna': [
            'House #1, Lane #5, Sonadanga',
            'Apartment #6, Block #F, Khalishpur',
            'Plot #7, DA Khan Road',
            'Flat #2, Building #14, Moylapota',
            'House #11, Road #9, Tank Pukur Road'
        ],
        'Rajshahi': [
            'House #4, Lane #7, Motihar',
            'Apartment #3, Block #B, Seroil',
            'Plot #13, Chouhatta, Boalia',
            'Flat #6, Building #10, Shiroil',
            'House #17, Road #12, Boalia'
        ],
        'Barisal': [
            'House #10, Lane #3, Natullabad',
            'Apartment #8, Block #A, Kuakata',
            'Plot #14, Dapdapia, Bakerganj',
            'Flat #5, Building #4, Muladi',
            'House #19, Road #11, Natullabad'
        ],
        'Rangpur': [
            'House #3, Lane #9, Kotwali',
            'Apartment #7, Block #G, Pirgacha',
            'Plot #8, Bogra Road',
            'Flat #1, Building #13, Rangpur Sadar',
            'House #16, Road #10, Kaunia'
        ],
        'Comilla': [
            'House #6, Lane #6, Kandirpar',
            'Apartment #11, Block #H, Chandina',
            'Plot #12, Brahmanpara',
            'Flat #9, Building #15, Laksam',
            'House #20, Road #8, Chauddagram'
        ],
        'Narayanganj': [
            'House #5, Lane #4, Fatullah',
            'Apartment #10, Block #I, Narayanganj Sadar',
            'Plot #9, Rupganj',
            'Flat #7, Building #12, Sonargaon',
            'House #14, Road #7, Araihazar'
        ],
        'Gazipur': [
            'House #8, Lane #10, Joydebpur',
            'Apartment #13, Block #J, Tongi',
            'Plot #4, Sreepur',
            'Flat #11, Building #16, Kaliakair',
            'House #12, Road #2, Gazipur Sadar'
        ],
        'Tangail': [
            'House #2, Lane #8, Santosh',
            'Apartment #5, Block #K, Bhuapur',
            'Plot #7, Mirzapur',
            'Flat #3, Building #14, Kalihati',
            'House #16, Road #11, Gopalpur'
        ],
        'Mymensingh': [
            'House #10, Lane #6, Mymensingh Sadar',
            'Apartment #9, Block #L, Bhaluka',
            'Plot #5, Trishal',
            'Flat #4, Building #13, Gafargaon',
            'House #18, Road #9, Muktagacha'
        ],
        'Coxs Bazar': [
            'House #3, Lane #7, Coxs Bazar Sadar',
            'Apartment #8, Block #M, Chakaria',
            'Plot #14, Ukhia',
            'Flat #11, Building #15, Teknaf',
            'House #20, Road #5, Ramu'
        ],
        'Jessore': [
            'House #4, Lane #12, Jessore Sadar',
            'Apartment #7, Block #N, Jhikargachha',
            'Plot #8, Manirampur',
            'Flat #1, Building #10, Abhaynagar',
            'House #15, Road #3, Bagherpara'
        ],
        'Narsingdi': [
            'House #5, Lane #9, Narsingdi Sadar',
            'Apartment #12, Block #O, Belabo',
            'Plot #13, Monohardi',
            'Flat #8, Building #16, Raipura',
            'House #19, Road #4, Shibpur'
        ],
        'Kushtia': [
            'House #7, Lane #11, Kushtia Sadar',
            'Apartment #10, Block #P, Mirpur',
            'Plot #6, Kumarkhali',
            'Flat #2, Building #9, Daulatpur',
            'House #14, Road #8, Bheramara'
        ],
        'Bogura': [
            'House #9, Lane #10, Bogura Sadar',
            'Apartment #6, Block #Q, Shibganj',
            'Plot #7, Sherpur',
            'Flat #13, Building #12, Kahalu',
            'House #18, Road #4, Sonatala'
        ],
        'Dinajpur': [
            'House #2, Lane #8, Dinajpur Sadar',
            'Apartment #5, Block #R, Birganj',
            'Plot #9, Phulbari',
            'Flat #3, Building #14, Chirirbandar',
            'House #16, Road #6, Khansama'
        ],
        'Faridpur': [
            'House #10, Lane #7, Faridpur Sadar',
            'Apartment #9, Block #S, Boalmari',
            'Plot #5, Charbhadrasan',
            'Flat #2, Building #13, Nagarkanda',
            'House #19, Road #3, Sadarpur'
        ],
        'Jamalpur': [
            'House #4, Lane #12, Jamalpur Sadar',
            'Apartment #7, Block #T, Melandaha',
            'Plot #8, Islampur',
            'Flat #1, Building #10, Sarishabari',
            'House #15, Road #5, Dewanganj'
        ]
    }

    return random.choice(city_addresses[city]) + ', ' + city

# Function to generate random 11-digit Bangladeshi phone numbers
def generate_phone_number():
    return f'+8801{random.randint(3, 9)}-{random.randint(100, 999)}-{random.randint(10000, 99999)}'

# Function to generate random data for the table
def generate_data():
    cities = ['Dhaka', 'Chittagong', 'Sylhet', 'Khulna', 'Rajshahi', 'Barisal', 'Rangpur', 'Comilla', 'Narayanganj',
              'Gazipur', 'Tangail', 'Mymensingh', 'Coxs Bazar', 'Jessore', 'Narsingdi', 'Kushtia', 'Bogura', 'Dinajpur',
              'Faridpur', 'Jamalpur']
    brands = {
        'Celina': 5599,
        'Khaadi': 5990,
        'Sapphire': 7180,
        'Mushq': 6890,
        'Baroque': 7560,
        'Sana Safinaz': 10590,
        'Ethnic': 6500,
        'Maria B.': 7500,
        'Faraz Manan': 90000,
        'Amir Adnan': 9550
    }

    data = []
    for i in range(1, 5001):
        gender = 'Female' if i <= 4000 else 'Male'
        if i <= 0.35 * 5000:
            city = 'Dhaka'
            delivery_charge = 70
        elif i <= (0.35 + 0.20) * 5000:
            city = 'Chittagong'
            delivery_charge = 120
        else:
            city = random.choice(list(set(cities) - {'Dhaka', 'Chittagong'}))
            delivery_charge = 120
        address = generate_address(city)
        brand_name, brand_price = random.choice(list(brands.items()))
        product_price = brand_price
        total_bill = product_price + delivery_charge
        phone_number = generate_phone_number()

        data.append([i, generate_bengali_name(gender), gender, city, address, brand_name, product_price, total_bill, phone_number, delivery_charge])

    # Shuffle the list
    random.shuffle(data)

    return data

# Function to write data to a CSV file
def write_to_csv(data):
    with open('clients_data_5000_shuffled.csv', mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        # Writing the header
        writer.writerow(['Customer Id', 'Customer Name', 'Gender', 'City', 'Address', 'Product Details (Brand)', 'Product Price (Taka)', 'Total Bill (Taka)', 'Phone Number', 'Delivery Charge (Taka)'])
        # Writing the data
        writer.writerows(data)

# Generate data and write to CSV file
data_to_write = generate_data()
write_to_csv(data_to_write)

print("CSV file 'clients_data_5000_shuffled.csv' has been generated with shuffled data and specified city distribution.")
# Out:
# CSV file 'clients_data_5000_shuffled.csv' has been generated with shuffled data and specified city distribution.
